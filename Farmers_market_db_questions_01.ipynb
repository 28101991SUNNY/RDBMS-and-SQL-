# %%
pd.set_option('display.max_rows',5000)
import mysql.connector as connection
import pymysql
dbname = "farmers_market"
dbhost = "localhost"
dbusername = "root"
dbpassword = "9723811710"
conn = pymysql.connect(host = dbhost,
                           port = int(3306),
                             user = "root",
                             passwd = dbpassword,
                            db = dbname)
# %load_ext sql
# %sql mysql+mysqldb://root:9723811710@localhost/farmers_market

# %%
tables = pd.read_sql_query("SHOW TABLES FROM farmers_market",conn)
tables = list(tables["Tables_in_farmers_market"])
for tables in tables:
    o = (pd.read_sql_query("describe {}".format(tables),conn))
    print(tables)
    print(o)
# Out:
# booth
#                Field          Type Null  Key Default Extra
# 0       booth_number           int   NO  PRI    None
# 1  booth_price_level   varchar(45)   NO         None
# 2  booth_description  varchar(255)   NO         None
# 3         booth_type   varchar(45)   NO         None
# customer
#                  Field         Type Null  Key Default Extra
# 0          customer_id          int   NO  PRI    None
# 1  customer_first_name  varchar(45)  YES         None
# 2   customer_last_name  varchar(45)  YES         None
# 3         customer_zip  varchar(45)  YES         None
# customer_purchases
#                       Field           Type Null  Key Default Extra
# 0                product_id            int   NO  PRI    None
# 1                 vendor_id            int   NO  PRI    None
# 2               market_date           date   NO  PRI    None
# 3               customer_id            int   NO  PRI    None
# 4                  quantity  decimal(16,2)  YES         None
# ...

# %%
pd.read_sql_query("select * from customer_purchases",conn)
# Out:
#       product_id  vendor_id market_date  customer_id  quantity  \
# 0              1          7  2019-07-03           14      0.99
# 1              1          7  2019-07-03           14      2.18
# 2              1          7  2019-07-03           15      1.53
# 3              1          7  2019-07-03           16      2.02
# 4              1          7  2019-07-03           22      0.66
# 5              1          7  2019-07-06            4      0.27
# 6              1          7  2019-07-06           12      3.60
# 7              1          7  2019-07-06           14      3.04
# 8              1          7  2019-07-06           23      1.49
# 9              1          7  2019-07-06           23      2.56
# 10             1          7  2019-07-10            3      2.48
# 11             1          7  2019-07-10            4      2.13
# 12             1          7  2019-07-10            8      2.71
# 13             1          7  2019-07-10           23      3.61
# ...

# %% [markdown]
# ## Q:  GET ALL THE PRODUCTS AVAILABLE IN THE MARKET :

# %%
pd.read_sql_query("""

SELECT * FROM
product;

""",conn)
# Out:
#     product_id                           product_name    product_size  \
# 0            1             Habanero Peppers - Organic          medium
# 1            2             Jalapeno Peppers - Organic           small
# 2            3              Poblano Peppers - Organic           large
# 3            4                   Banana Peppers - Jar            8 oz
# 4            5                      Whole Wheat Bread         1.5 lbs
# 5            6                    Cut Zinnias Bouquet          medium
# 6            7                              Apple Pie             10"
# 7            8                             Cherry Pie             10"
# 8            9                         Sweet Potatoes          medium
# 9           10                                   Eggs         1 dozen
# 10          11                             Pork Chops            1 lb
# 11          12           Baby Salad Lettuce Mix - Bag          1/2 lb
# ...

# %% [markdown]
# ### Q : EXPLORE VENDOR_BOOTH_ASSIGNMENTS:
# ### LIST DOWN 10 ROWS OF FARMERS MARKET VENDOR BOOTH ASSIGHMENTS , DISPLAYING THE MAKRET_DATE,
# ### VENDOR_ID, AND BOOTH NUMBER FROM VENDOR BOOTH ASSIGHMENT TABLE .

# %%
# %%sql
#
# select
#    market_date,
#    vendor_id,
#    booth_number
# from
#    vendor_booth_assignments
# limit 10;
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 10 rows affected.
# [(datetime.date(2019, 4, 3), 1, 2),
#  (datetime.date(2019, 4, 3), 3, 1),
#  (datetime.date(2019, 4, 3), 4, 7),
#  (datetime.date(2019, 4, 3), 7, 11),
#  (datetime.date(2019, 4, 3), 8, 6),
#  (datetime.date(2019, 4, 3), 9, 8),
#  (datetime.date(2019, 4, 6), 1, 2),
#  (datetime.date(2019, 4, 6), 3, 1),
#  (datetime.date(2019, 4, 6), 4, 7),
#  (datetime.date(2019, 4, 6), 7, 11)]

# %%
#
#do not prefer to use select * from table to glance into table , 
#that increase processing load on pipeline unnecessarily,
#and increase company cost.

# %% [markdown]
# #### # SORT data by market_date:
# ORDER BY :

# %%
# %%sql
#
# select
#    market_date,
#    vendor_id,
#    booth_number
# from
#    vendor_booth_assignments
# order by
#    market_date asc ;
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 921 rows affected.
# [(datetime.date(2019, 4, 3), 1, 2),
#  (datetime.date(2019, 4, 3), 3, 1),
#  (datetime.date(2019, 4, 3), 4, 7),
#  (datetime.date(2019, 4, 3), 7, 11),
#  (datetime.date(2019, 4, 3), 8, 6),
#  (datetime.date(2019, 4, 3), 9, 8),
#  (datetime.date(2019, 4, 6), 1, 2),
#  (datetime.date(2019, 4, 6), 3, 1),
#  (datetime.date(2019, 4, 6), 4, 7),
#  (datetime.date(2019, 4, 6), 7, 11),
#  (datetime.date(2019, 4, 6), 8, 6),
#  (datetime.date(2019, 4, 6), 9, 8),
#  (datetime.date(2019, 4, 10), 1, 7),
#  (datetime.date(2019, 4, 10), 3, 1),
#  (datetime.date(2019, 4, 10), 4, 2),
#  (datetime.date(2019, 4, 10), 7, 11),
#  (datetime.date(2019, 4, 10), 8, 6),
#  (datetime.date(2019, 4, 10), 9, 8),
#  (datetime.date(2019, 4, 13), 1, 2),
#  (datetime.date(2019, 4, 13), 3, 1),
#  (datetime.date(2019, 4, 13), 4, 7),
#  (datetime.date(2019, 4, 13), 7, 11),
#  (datetime.date(2019, 4, 13), 8, 6),
# ...

# %% [markdown]
# ### Q : IN THE CUSTOMER_PURCHASES TABLE WE HVE ALL HE TRANSACTIONS : QUANTITY AND COST : GET THE TOTAL AMOUNT :

# %%
pd.read_sql_query("""

select 
	market_date,
	customer_id,
	quantity,
	cost_to_customer_per_qty,
	(quantity * cost_to_customer_per_qty) as 'Total Amt per Transaction'
from 
	customer_purchases;

""",conn).head(10)
# Out:
#   market_date  customer_id  quantity  cost_to_customer_per_qty  \
# 0  2019-07-03           14      0.99                      6.99
# 1  2019-07-03           14      2.18                      6.99
# 2  2019-07-03           15      1.53                      6.99
# 3  2019-07-03           16      2.02                      6.99
# 4  2019-07-03           22      0.66                      6.99
# 5  2019-07-06            4      0.27                      6.99
# 6  2019-07-06           12      3.60                      6.99
# 7  2019-07-06           14      3.04                      6.99
# 8  2019-07-06           23      1.49                      6.99
# 9  2019-07-06           23      2.56                      6.99
#
#    Total Amt per Transaction
# 0                     6.9201
# 1                    15.2382
# 2                    10.6947
# 3                    14.1198
# 4                     4.6134
# 5                     1.8873
# 6                    25.1640
# 7                    21.2496
# ...

# %% [markdown]
#     ROUND UP THE TOTAL AMOUNT PER TRANSACTION
#
#     select
#         market_date,
#         customer_id,
#         quantity,
#         cost_to_customer_per_qty,
#         ROUND((quantity * cost_to_customer_per_qty),2) as 'Total Amt per Transaction'
#     from
#         customer_purchases;

# %% [markdown]
#     SELECT ROUND(5600,-3); -- 6000
#     SELECT ROUND(5600,-2);  -- 5600
#     SELECT ROUND(5400,-3);  -- 5000
#     SELECT ROUND(5400,-4);  -- 10000
#     SELECT ROUND(4400,-4);  -- 0
#     SELECT CEIL(12.5); -- 13
#     SELECT fLOOR(12.5); -- 12

# %% [markdown]
#     Q : FIRST NAME AND LAST NAME WITH A SPACE
#
#      SELECT
#         customer_first_name,
#        customer_last_name,
#        concat(customer_first_name ," ", customer_last_name) as full_name
#     from
#         customer;
#     -------------------------------- full name in upper case
#     SELECT
#         customer_first_name,
#         customer_last_name,
#         UPPER(concat(customer_first_name ," ", customer_last_name)) as full_name
#     from
#         customer;
#     --------------------------------- first name as it is , last name in upper case
#     SELECT
#         customer_first_name,
#         customer_last_name,
#         concat(customer_first_name ," ", UPPER(customer_last_name)) as full_name
#     from
#         customer;

# %% [markdown]
# ### Q : EXTRACT ALL THE PRODUCT NAMES THAT ARE PART OF PRODUCT_CATEGOTY 1 :

# %%
# %%sql
#
# SELECT
# 	product_id,
# 	product_category_id,
# 	product_name
# FROM
# 	product
# WHERE
# 	product_category_id = 1;
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 13 rows affected.
# [(1, 1, 'Habanero Peppers - Organic'),
#  (2, 1, 'Jalapeno Peppers - Organic'),
#  (3, 1, 'Poblano Peppers - Organic'),
#  (9, 1, 'Sweet Potatoes'),
#  (12, 1, 'Baby Salad Lettuce Mix - Bag'),
#  (13, 1, 'Baby Salad Lettuce Mix'),
#  (14, 1, 'Red Potatoes'),
#  (15, 1, 'Red Potatoes - Small'),
#  (16, 1, 'Sweet Corn'),
#  (17, 1, 'Carrots'),
#  (18, 1, 'Carrots - Organic'),
#  (21, 1, 'Organic Cherry Tomatoes'),
#  (22, 1, 'Roma Tomatoes')]

# %% [markdown]
# #### Q :   PRINT A REPORT OF EVERTHING CUSTOMER_UD 4 HAS EVER PURCHASED AT FARMER'S MARKET. SORT BY MARKET DATA , VENDOR_ID AND PRODUCT_ID

# %%
# %%sql
# SELECT
# 	*,
#    ROUND((quantity * cost_to_customer_per_qty),2) as Total_Amount
# FROM
# 	customer_purchases
# WHERE
# 	customer_id = 4
# ORDER BY
# 	market_date,
#    vendor_id,
#    product_id;
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 258 rows affected.
# [(4, 7, datetime.date(2019, 4, 3), 4, Decimal('1.00'), Decimal('4.00'), datetime.timedelta(seconds=65340), Decimal('4.00')),
#  (5, 8, datetime.date(2019, 4, 6), 4, Decimal('1.00'), Decimal('6.50'), datetime.timedelta(seconds=31440), Decimal('6.50')),
#  (4, 7, datetime.date(2019, 4, 10), 4, Decimal('5.00'), Decimal('4.00'), datetime.timedelta(seconds=60480), Decimal('20.00')),
#  (4, 7, datetime.date(2019, 4, 10), 4, Decimal('3.00'), Decimal('4.00'), datetime.timedelta(seconds=62820), Decimal('12.00')),
#  (7, 8, datetime.date(2019, 4, 10), 4, Decimal('2.00'), Decimal('18.00'), datetime.timedelta(seconds=68040), Decimal('36.00')),
#  (4, 7, datetime.date(2019, 4, 13), 4, Decimal('2.00'), Decimal('4.00'), datetime.timedelta(seconds=37020), Decimal('8.00')),
#  (4, 7, datetime.date(2019, 4, 17), 4, Decimal('4.00'), Decimal('3.50'), datetime.timedelta(seconds=64260), Decimal('14.00')),
# ...

# %% [markdown]
# #### Q : GET ALL PRODUCT INFO , WITH ID BETWEEN 3 AND 8 , AND ALSO 10 .

# %%
# %%sql
#
# SELECT
# *
# FROM
# 	product
# WHERE
# 	(product_id > 3 and product_id < 8) OR (product_id = 10);      -- not included 3 and 8
#
# SELECT
# *
# FROM
# 	product
# WHERE
# 	(product_id between  3 and 8) OR (product_id = 10);       -- includes 3 and 8 both
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 5 rows affected.
# 7 rows affected.
# [(3, 'Poblano Peppers - Organic', 'large', 1, 'unit'),
#  (4, 'Banana Peppers - Jar', '8 oz', 3, 'unit'),
#  (5, 'Whole Wheat Bread', '1.5 lbs', 3, 'unit'),
#  (6, 'Cut Zinnias Bouquet', 'medium', 5, 'unit'),
#  (7, 'Apple Pie', '10"', 3, 'unit'),
#  (8, 'Cherry Pie', '10"', 3, 'unit'),
#  (10, 'Eggs', '1 dozen', 6, 'unit')]

# %%
# %%sql
# select
# customer_id,
# customer_first_name,
# customer_last_name
# from
# customer
# where LOWER(customer_first_name) = "carloz" or
# 	LOWER(customer_last_name) = "diaz";
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 2 rows affected.
# [(2, 'Manuel', 'Diaz'), (17, 'Carlos', 'Diaz')]

# %% [markdown]
# #### Q  : FIND BOOTH ASSIGMENTS FOR VENDOR 7 FOR ANY MARKET DATE BETWEEN ARPIL 3 2019 AND MAY 16 2019 INCLUDE BOTH DATES .

# %%
# %%sql
#
# SELECT
#    *
# FROM
# 	vendor_booth_assignments
# WHERE
#    (vendor_id = 7) AND (market_date BETWEEN '2019-04-03' AND '2019-05-16')
# ;
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 13 rows affected.
# [(7, 11, datetime.date(2019, 4, 3)),
#  (7, 11, datetime.date(2019, 4, 6)),
#  (7, 11, datetime.date(2019, 4, 10)),
#  (7, 11, datetime.date(2019, 4, 13)),
#  (7, 11, datetime.date(2019, 4, 17)),
#  (7, 11, datetime.date(2019, 4, 20)),
#  (7, 11, datetime.date(2019, 4, 24)),
#  (7, 11, datetime.date(2019, 4, 27)),
#  (7, 11, datetime.date(2019, 5, 1)),
#  (7, 11, datetime.date(2019, 5, 4)),
#  (7, 11, datetime.date(2019, 5, 8)),
#  (7, 11, datetime.date(2019, 5, 11)),
#  (7, 11, datetime.date(2019, 5, 15))]

# %% [markdown]
# #### Q : RETURN A LIST OF CUSTOMERS WITH SELECTED LAST NAMES : [Diaz, Edwards and Wilson]

# %%
# %%sql
#
# SELECT
#    customer_first_name,
#    customer_last_name,
#    customer_id
# FROM
#    customer
# WHERE
#    customer_last_name in ('Diaz', 'Edwards','Wilson');
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 4 rows affected.
# [('Manuel', 'Diaz', 2),
#  ('Bob', 'Wilson', 3),
#  ('Russell', 'Edwards', 10),
#  ('Carlos', 'Diaz', 17)]

# %% [markdown]
# #### Q : WANT TO GET THE DATA ABOUT A CUSTOMER YOU KNEW AS JERRY'    BUT NOT SURE HE WAS LISTED IN DATABASE AS JERRY OR JEREMY OR JEREMIAH.

# %%
# %%sql
#
# SELECT
#    *
# FROM
#    customer
# WHERE
#    customer_first_name like "Jer%";
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 2 rows affected.
# [(13, 'Jeremy', 'Gruber', '22821'), (18, 'Jeri', 'Mitchell', '22802')]

# %% [markdown]
# #### Q :  FIND ALL THE PRODUCTS WHICH HAVE NO SIZE RECORDED AGAINST THEM .

# %%
# %%sql
#
# SELECT
#    *
# FROM
#    product
# WHERE product_size is null;
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 1 rows affected.
# [(14, 'Red Potatoes', None, 1, None)]

# %%
#  -- full prof condition for missing value

# %%
# %%sql
#
# SELECT
#    *
# FROM
#    product
# WHERE (product_size is null) OR (product_size = "");
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 1 rows affected.
# [(14, 'Red Potatoes', None, 1, None)]

# %% [markdown]
# #### Q : ANALYZE PURCHASES MADE AT THE FARMERS MARKET ON DAYS WHEN IT RAINED.

# %%
# %%sql
#
# SELECT
#     market_date,
#     customer_id,
#     quantity,
#     cost_to_customer_per_qty,
#     ROUND((quantity * cost_to_customer_per_qty),2) AS 'Total Amt per Transaction'
# FROM
# 	customer_purchases
# WHERE
#    market_date IN (
#                   SELECT
#                      DISTINCT(market_date)
#                   FROM
#                      market_date_info
#                   WHERE
#                      market_rain_flag = 1
#                       )
#  ;
# Out:
#  * mysql+mysqldb://root:***@localhost/farmers_market
# 381 rows affected.
# [(datetime.date(2019, 7, 31), 3, Decimal('2.64'), Decimal('6.99'), Decimal('18.45')),
#  (datetime.date(2019, 7, 31), 8, Decimal('3.83'), Decimal('6.99'), Decimal('26.77')),
#  (datetime.date(2019, 7, 31), 19, Decimal('3.69'), Decimal('6.99'), Decimal('25.79')),
#  (datetime.date(2019, 7, 31), 22, Decimal('1.07'), Decimal('6.99'), Decimal('7.48')),
#  (datetime.date(2019, 9, 21), 6, Decimal('1.99'), Decimal('6.99'), Decimal('13.91')),
#  (datetime.date(2019, 9, 21), 24, Decimal('1.82'), Decimal('6.99'), Decimal('12.72')),
#  (datetime.date(2019, 9, 21), 24, Decimal('4.40'), Decimal('6.99'), Decimal('30.76')),
#  (datetime.date(2020, 7, 8), 4, Decimal('4.44'), Decimal('6.99'), Decimal('31.04')),
#  (datetime.date(2020, 7, 8), 8, Decimal('0.84'), Decimal('6.99'), Decimal('5.87')),
#  (datetime.date(2020, 7, 8), 10, Decimal('1.33'), Decimal('6.99'), Decimal('9.30')),
# ...

# %% [markdown]
# # EXECUTION ORDER IN SQL :
#
#     FROM
#     WHERE
#     GROUP BY
#     AGGREGATES
#     HAVING
#     WINDOW FUNCTIONS
#     SELECT
#     DISTINCT
#     UNION/INTERSECT/EXCEPT
#     ORDER BY
#     OFFSET
#     LIMIT/FETCH/TOP

# %% [markdown]
#     CASE WHEN THEN END statement :
#
#
#
#     SELECT
#       cols,
#       CASE WHEN colName condition THEN expression
#            ELSE condition
#            END AS col_alias
#     FROM
#       tablename

# %% [markdown]
# #### Q : GET THE REPORT OF ALL THE VENDORS WHO PRIMARILY SELL FRESH PRODUCE AND WHO DONT AND MAKR IT IN FRONT OF THEIR NAMES.

# %%
pd.read_sql_query("""

SELECT 
    vendor_id,
    vendor_name,
    concat(vendor_owner_first_name," ",vendor_owner_last_name) AS vendor_full_name,
    vendor_type,
    CASE WHEN vendor_type LIKE "%fresh%"  THEN "Fresh"
         ELSE "Other"
         END AS "Fresh/Other"
FROM
	  vendor
 ;
""",conn).head(10)
# Out:
#    vendor_id                       vendor_name vendor_full_name  \
# 0          1  Chris's Sustainable Eggs & Meats     Chris Sylvan
# 1          2         Hernández Salsa & Veggies  Maria Hernández
# 2          3          Mountain View Vegetables     Joseph Yoder
# 3          4                    Fields of Corn     Samuel Smith
# 4          5                Seashell Clay Shop      Karen Soula
# 5          6          Mother's Garlic & Greens      Vera Gordon
# 6          7                   Marco's Peppers    Marco Bokashi
# 7          8                      Annie's Pies    Annie Aquinas
# 8          9              Mediterranean Bakery       Kani Hardi
#
#                      vendor_type Fresh/Other
# 0                   Eggs & Meats       Other
# 1  Fresh Variety: Veggies & More       Fresh
# 2  Fresh Variety: Veggies & More       Fresh
# 3                  Fresh Focused       Fresh
# 4                 Arts & Jewelry       Other
# 5  Fresh Variety: Veggies & More       Fresh
# ...

# %% [markdown]
# #### Q : IF MARKET_DAY IS SATURDAY OR SUNDAY , MARK IT AS WEEKEND OR WEEKDAY .

# %%
 pd.read_sql_query("""

 SELECT
 market_date,
 market_day,
 CASE WHEN market_day in ("Saturday","Sunday") THEN "Weekend"
	  ELSE "Weekday"
      END AS WeekdayOrNOT
FROM
	market_date_info;
    
    """,conn).head(10)
# Out:
#   market_date market_day WeekdayOrNOT
# 0  2019-03-02   Saturday      Weekend
# 1  2019-03-09   Saturday      Weekend
# 2  2019-03-13  Wednesday      Weekday
# 3  2019-03-16   Saturday      Weekend
# 4  2019-03-20  Wednesday      Weekday
# 5  2019-03-23   Saturday      Weekend
# 6  2019-03-27  Wednesday      Weekday
# 7  2019-03-30   Saturday      Weekend
# 8  2019-04-03  Wednesday      Weekday
# 9  2019-04-06   Saturday      Weekend

# %% [markdown]
# #### Q : PUT THE TOTAL COST TO CUSTOMER PURCHASES INTO BINS OF
# ####      UNDER 5  ,    5-9.99   ,  10-19.99 ,    20 AND ABOVE.

# %%
 pd.read_sql_query("""

 
SELECT
	  market_date,
    customer_id,
    round((quantity * cost_to_customer_per_qty),2) as TotalAmount,
    CASE WHEN (quantity * cost_to_customer_per_qty) < 5 THEN "UNDER $5"
		     WHEN (quantity * cost_to_customer_per_qty) < 10 THEN "$5-$9.99"
         WHEN (quantity * cost_to_customer_per_qty) < 20 THEN "$10-$19.99"
         ELSE "ABOVE $20" 
         END AS price_bins
FROM
	customer_purchases;
 

    
    """,conn).head(10)
# Out:
#   market_date  customer_id  TotalAmount  price_bins
# 0  2019-07-03           14         6.92    $5-$9.99
# 1  2019-07-03           14        15.24  $10-$19.99
# 2  2019-07-03           15        10.69  $10-$19.99
# 3  2019-07-03           16        14.12  $10-$19.99
# 4  2019-07-03           22         4.61    UNDER $5
# 5  2019-07-06            4         1.89    UNDER $5
# 6  2019-07-06           12        25.16   ABOVE $20
# 7  2019-07-06           14        21.25   ABOVE $20
# 8  2019-07-06           23        10.42  $10-$19.99
# 9  2019-07-06           23        17.89  $10-$19.99

# %% [markdown]
# #### Q : LETS SAY WE WANTED TO LIST EACH PRODUCT NAME ALONG WITH ITS PRODUCT CATEGORY NAME :

# %%
pd.read_sql_query("""


SELECT 
		p.product_name,
		pc.product_category_name,
		pc.product_category_id
FROM 
		product AS p
LEFT JOIN 
		product_category AS pc
	ON
		p.product_category_id = pc.product_category_id;
            
    """,conn).head(10)
# Out:
#                  product_name          product_category_name  \
# 0  Habanero Peppers - Organic      Fresh Fruits & Vegetables
# 1  Jalapeno Peppers - Organic      Fresh Fruits & Vegetables
# 2   Poblano Peppers - Organic      Fresh Fruits & Vegetables
# 3        Banana Peppers - Jar         Packaged Prepared Food
# 4           Whole Wheat Bread         Packaged Prepared Food
# 5         Cut Zinnias Bouquet               Plants & Flowers
# 6                   Apple Pie         Packaged Prepared Food
# 7                  Cherry Pie         Packaged Prepared Food
# 8              Sweet Potatoes      Fresh Fruits & Vegetables
# 9                        Eggs  Eggs & Meat (Fresh or Frozen)
#
#    product_category_id
# 0                    1
# 1                    1
# 2                    1
# 3                    3
# 4                    3
# 5                    5
# 6                    3
# 7                    3
# 8                    1
# 9                    6

# %% [markdown]
# #### Q : GET DETAILS OF ALL VENDORS SELLING FRESH FRUITS AND VEGIES WITH PRODUCT NAMES AND QUANTITY IN THE INVENTORY.

# %%
pd.read_sql_query("""


SELECT 
    v.vendor_id,
    p.product_name,
    pc.product_category_name,
    vi.quantity
FROM 
    vendor  as v
    left join vendor_inventory as vi 
          ON vi.vendor_id = v.vendor_id
    left join product as p 
          ON p.product_id = vi.product_id
    left join product_category as pc 
          ON pc.product_category_id = p.product_category_id
WHERE
  	pc.product_category_name LIKE "%fresh%";
    
    
    """,conn).head(10)
# Out:
#    vendor_id                product_name      product_category_name  quantity
# 0          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables      7.38
# 1          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables     10.96
# 2          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables     13.08
# 3          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables     10.22
# 4          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables     10.59
# 5          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables      9.04
# 6          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables     10.66
# 7          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables      6.76
# 8          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables     11.23
# 9          7  Habanero Peppers - Organic  Fresh Fruits & Vegetables     10.72

# %% [markdown]
# #### Q : GET ALL CUSTOMERS INFORMATION WHO HAVE NOT PURCHASED ANYTHING FROM THE MARKET :

# %%
pd.read_sql_query("""


SELECT 
  c.*
FROM  
  customer as c
LEFT JOIN 
  customer_purchases as cp
	  ON c.customer_id = cp.customer_id
WHERE 
  cp.customer_id IS NULL;
  
    """,conn).head(10)
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_first_name, customer_last_name, customer_zip]
# Index: []

# %% [markdown]
# #### Q : WRITE QUERY THAT RETURNS A LIST OF ALL CUSTOMERS WHO DID NOT MAKE PURCAHSES ON - APRIL 3rd 2019.

# %%
pd.read_sql_query("""


select
c.*
from customer as c
where c.customer_id not in
		(
        select 
        distinct(cp.customer_id)
        from 
        customer_purchases as cp
        where cp.market_date = "2019-04-03" 
        );
     """,conn).head(10)
# Out:
#    customer_id customer_first_name customer_last_name customer_zip
# 0            1                Jane             Connor        22801
# 1            2              Manuel               Diaz        22821
# 2            8               Norma         Valenzuela        22821
# 3           13              Jeremy             Gruber        22821
# 4           14             William              Lopes        22801
# 5           15             Darrell            Messina        22801
# 6           17              Carlos               Diaz        22802
# 7           18                Jeri           Mitchell        22802
# 8           19                 Iva           Kienzler        22802
# 9           21               Duane               Sipp        22801

# %% [markdown]
# #### Q : WE WANT DETAILS ABOUT ALL THE BOOTHS AS WELL AS EVERY VENDOR BOOTH ASSIGNMENTS ALONG WTH VENDOR DETAILS.

# %%
pd.read_sql_query("""

 SELECT 
     distinct
     b.booth_number,
     b.booth_type,
     v.vendor_name,
     v.vendor_type
 from
     booth as b
     left join vendor_booth_assignments as vba
	        on vba.booth_number = b.booth_number
     left join vendor as v
	        on v.vendor_id = vba.vendor_id
          
          ;
     """,conn).head(10)
# Out:
#    booth_number booth_type                       vendor_name  \
# 0             1   Standard          Mountain View Vegetables
# 1             2   Standard  Chris's Sustainable Eggs & Meats
# 2             2   Standard                    Fields of Corn
# 3             3      Small                              None
# 4             4      Small                              None
# 5             5      Small                              None
# 6             6      Small                      Annie's Pies
# 7             7   Standard  Chris's Sustainable Eggs & Meats
# 8             7   Standard                    Fields of Corn
# 9             7   Standard                      Annie's Pies
#
#                      vendor_type
# 0  Fresh Variety: Veggies & More
# 1                   Eggs & Meats
# 2                  Fresh Focused
# 3                           None
# 4                           None
# 5                           None
# 6                 Prepared Foods
# ...

# %% [markdown]
# #### Q : GET A LIST OF CUSTOMER_IDS WHO MADE PURCHASES ON EACH MARKET DATE :
#
#
#
#      SELECT
#         market_date,
#         customer_id
#      FROM
#          customer_purchases
#      GROUP BY
#          market_date ,customer_id;
#
#
#     -------
#
#     SELECT
#             distinct
#             market_date,
#             customer_id
#     FROM
#             customer_purchases
#      ;

# %%
# %%sql
# SELECT 
#     market_date,
#     customer_id
#  FROM 
#      customer_purchases 
#  GROUP BY 
#      market_date ,customer_id;

# %%
# %%sql
# SELECT 
#         distinct
#         market_date,
#         customer_id
# FROM 
#         customer_purchases 
#  ;

# %% [markdown]
# #### Q : COUNT  THE NUMBER OF CUSTOMERS WHO MADE PURCHASES ON EACH MARKET DATE :

# %%
pd.read_sql_query("""


SELECT 
	market_date,
	count(distinct(customer_id))
FROM 
	customer_purchases 
GROUP BY 
	market_date ;
    
         """,conn).head(10)
# Out:
#   market_date  count(distinct(customer_id))
# 0  2019-04-03                            12
# 1  2019-04-06                            13
# 2  2019-04-10                            10
# 3  2019-04-13                            13
# 4  2019-04-17                            13
# 5  2019-04-20                            14
# 6  2019-04-24                            14
# 7  2019-04-27                            15
# 8  2019-05-01                            12
# 9  2019-05-04                            15

# %% [markdown]
# #### Q : COUNT THE NUMBER OF PURCHASES EACH CUSTOMER MADE PER MARKET DATE :

# %%
 pd.read_sql_query("""

 SELECT
     market_date,
     customer_id,
     COUNT(1) AS "Number of product purchased"
 FROM
     customer_purchases
 GROUP BY 
     market_date,
     customer_id;
     
     
      """,conn).head(10)
# Out:
#   market_date  customer_id  Number of product purchased
# 0  2019-07-20            1                            3
# 1  2020-07-11            1                            3
# 2  2020-07-22            1                            3
# 3  2020-08-26            1                            5
# 4  2020-09-05            1                            4
# 5  2020-09-09            1                            2
# 6  2019-07-13            1                            2
# 7  2019-07-17            1                            5
# 8  2019-08-07            1                            3
# 9  2019-08-14            1                            1

# %% [markdown]
# #### Q : HOW MANY DIFFERENT KINDS OF PRODUCTS WERE PURCHASED BY EACH CUSTOMERS ON EACH MARKET DATE :

# %%
pd.read_sql_query("""
 
 SELECT
     market_date,
     customer_id,
     COUNT(distinct(product_id)) AS "Number of distinct product purchased"
 FROM
     customer_purchases
 GROUP BY 
     1,
     2;


     """,conn).head(10)
# Out:
#   market_date  customer_id  Number of distinct product purchased
# 0  2019-04-03            3                                     1
# 1  2019-04-03            4                                     1
# 2  2019-04-03            5                                     2
# 3  2019-04-03            6                                     2
# 4  2019-04-03            7                                     1
# 5  2019-04-03            9                                     3
# 6  2019-04-03           10                                     2
# 7  2019-04-03           11                                     1
# 8  2019-04-03           12                                     2
# 9  2019-04-03           16                                     2

# %% [markdown]
#     COUNT(*)        COUNT(1)        COUNT(column_name)          COUNT(DISTINCT(column_name))
#
#     counts          counts          counts all                  counts only distinct values
#     all             all value       values                      does not include duplicatd values
#     values          execpt          includes
#     including       nulls           duplicates
#     nulls           includes
#     includes        duplicate
#     duplicated

# %% [markdown]
# #### Q : CALCULATE TOTAL QUANTITY PURCHASE BY EACH CUSTOMERS PER MARKET DATE :

# %%
pd.read_sql_query("""

 SELECT
     market_date,
     customer_id,
     SUM(quantity) AS "Total Quantity"
 FROM
     customer_purchases
 GROUP BY 
     market_date,
     customer_id;
     
     """,conn).head(10)
# Out:
#   market_date  customer_id  Total Quantity
# 0  2019-07-03           14            8.17
# 1  2019-07-03           15            1.53
# 2  2019-07-03           16            9.48
# 3  2019-07-03           22            8.66
# 4  2019-07-06            4            4.27
# 5  2019-07-06           12            3.60
# 6  2019-07-06           14           12.72
# 7  2019-07-06           23            6.05
# 8  2019-07-10            3            9.48
# 9  2019-07-10            4            2.13

# %% [markdown]
# #### Q : CALCULATE TOTAL AMOUNT SPENT BY EACH CUSTOMERS PER MARKET DATE :.

# %%
pd.read_sql_query("""

     SELECT
         market_date,
         customer_id,
         round(SUM(quantity*cost_to_customer_per_qty),2) AS "Total Amount"
     FROM
         customer_purchases
     GROUP BY 
         1,2;
         
         
     """,conn).head(10)
# Out:
#   market_date  customer_id  Total Amount
# 0  2019-07-03           14         42.16
# 1  2019-07-03           15         10.69
# 2  2019-07-03           16         38.70
# 3  2019-07-03           22          8.61
# 4  2019-07-06            4         17.89
# 5  2019-07-06           12         25.16
# 6  2019-07-06           14         34.10
# 7  2019-07-06           23         64.31
# 8  2019-07-10            3         31.34
# 9  2019-07-10            4         14.89

# %% [markdown]
# #### Q : CALCULATE THE TOTAL REVENUE OF MARKET :

# %%
pd.read_sql_query("""


SELECT
  round(SUM(quantity*cost_to_customer_per_qty),2) AS "Total Revenue"
FROM
  customer_purchases
;



     """,conn).head(10)
# Out:
#    Total Revenue
# 0       69227.14

# %% [markdown]
# #### Q : CALCULATE THE TOTAL SALE OF MARKET PER MARKET DATE: :

# %%
pd.read_sql_query("""

SELECT
  market_date,
  round(SUM(quantity*cost_to_customer_per_qty),2) AS "Total Revenue"
FROM
  customer_purchases
GROUP BY 
  market_date
ORDER BY 
  1;
  
  
       """,conn).head(10)
# Out:
#   market_date  Total Revenue
# 0  2019-04-03          475.0
# 1  2019-04-06          549.5
# 2  2019-04-10          505.0
# 3  2019-04-13          377.0
# 4  2019-04-17          493.5
# 5  2019-04-20          455.5
# 6  2019-04-24          366.0
# 7  2019-04-27          444.5
# 8  2019-05-01          523.0
# 9  2019-05-04          497.0

# %% [markdown]
# #### Q : CALCULATE TOTAL PRICE PAID BY CUSTOMER_ID 3 PER MARKET DATE :

# %%
pd.read_sql_query("""


SELECT 
    market_date,
    round(SUM(quantity*cost_to_customer_per_qty),2) as total_spent
FROM
    customer_purchases
WHERE 
    customer_id = 3
GROUP BY 
    market_date
ORDER BY 
    1;
    
    
    
     """,conn).head(10)
# Out:
#   market_date  total_spent
# 0  2019-04-03          4.0
# 1  2019-04-13         56.0
# 2  2019-04-24         20.0
# 3  2019-04-27         72.0
# 4  2019-05-01         52.0
# 5  2019-05-08         12.0
# 6  2019-05-11        108.0
# 7  2019-05-15         24.5
# 8  2019-05-22         96.5
# 9  2019-05-29         19.5

# %% [markdown]
# #### Q :  WHAT IF WE WANTE TO FIND OUT HOW MUCH A CUSTOMER HAD SPENT AT EACH VENDOR  , REGARDLESS OF DATE .

# %%
pd.read_sql_query("""


SELECT 
    cp.customer_id,
    cp.vendor_id,
    round(SUM(cp.quantity * cp.cost_to_customer_per_qty),2) as total_spent
FROM customer_purchases AS cp
LEFT JOIN vendor as v
	  on v.vendor_id = cp.vendor_id
GROUP BY 
    customer_id,
    cp.vendor_id
ORDER BY 
1;


     """,conn).head(10)
# Out:
#    customer_id  vendor_id  total_spent
# 0            1          4        88.70
# 1            1          7      1131.22
# 2            1          8      2311.00
# 3            2          4        71.90
# 4            2          7      1457.05
# 5            2          8      2650.50
# 6            3          4        78.90
# 7            3          7      1031.26
# 8            3          8      2722.00
# 9            4          4       147.20

# %% [markdown]
# #### Q : ADD SOME CUSTOMER DETAILS AND VENDOR DETAILS TO THERE RESULTS.

# %%
pd.read_sql_query("""


SELECT 
    cp.customer_id,
    concat(c.customer_first_name," ",c.customer_last_name) as customer_name,
    cp.vendor_id,
    v.vendor_name,
    round(SUM(cp.quantity * cp.cost_to_customer_per_qty),2) as total_spent
FROM 
    customer_purchases AS cp
LEFT JOIN 
    vendor as v
	      on v.vendor_id = cp.vendor_id
LEFT JOIN 
    customer as c
	      on c.customer_id = cp.customer_id
GROUP BY 
    customer_id,
    cp.vendor_id
ORDER BY 
1;


     """,conn).head(10)
# Out:
#    customer_id      customer_name  vendor_id      vendor_name  total_spent
# 0            1        Jane Connor          4   Fields of Corn        88.70
# 1            1        Jane Connor          7  Marco's Peppers      1131.22
# 2            1        Jane Connor          8     Annie's Pies      2311.00
# 3            2        Manuel Diaz          4   Fields of Corn        71.90
# 4            2        Manuel Diaz          7  Marco's Peppers      1457.05
# 5            2        Manuel Diaz          8     Annie's Pies      2650.50
# 6            3         Bob Wilson          4   Fields of Corn        78.90
# 7            3         Bob Wilson          7  Marco's Peppers      1031.26
# 8            3         Bob Wilson          8     Annie's Pies      2722.00
# 9            4  Deanna Washington          4   Fields of Corn       147.20

# %% [markdown]
# #### Q : WE WANT TO GET MOST AND LEAST EXPENSIVE ITEMS PER PRODUCT CATEGORY,  CONSIDERING THE FACT THAT EACH VENDOR SETS THEIR OWN PRICE AND CAN ADJUST PRICES PER CUSTOMER.

# %%
pd.read_sql_query("""


SELECT 

    pc.product_category_name,
    pc.product_category_id,
    min(vi.original_price) as min_price,
    max(vi.original_price) as max_price
    
FROM 
    vendor_inventory AS vi
    
    LEFT JOIN product as p
        on vi.product_id = p.product_id
    LEFT JOIN product_category as pc
        on p.product_category_id = pc.product_category_id

group by
    pc.product_category_id
;


     """,conn).head(10)
# Out:
#        product_category_name  product_category_id  min_price  max_price
# 0  Fresh Fruits & Vegetables                    1        0.5       6.99
# 1     Packaged Prepared Food                    3        4.0      18.00

# %% [markdown]
# #### Q :  FIND THE AVERAGE AMOUNT SPENT BY CUSTOMERS ON EACH DAY . WE WANT TO CONSIDER ONLY THOSE DAYS WHERE THE NUMBER OF PURCHASES WERE MORE THAN 3 AND THE TRANSCATION AMOUNT WAS GREATER THAN 5.

# %%
pd.read_sql_query("""


SELECT
    market_date,
    customer_id,
    count(1) as No_of_Transactions,
    round(avg((quantity * cost_to_customer_per_qty)),2) as avgspent
FROM
    customer_purchases
WHERE 
    (quantity * cost_to_customer_per_qty) > 5 
GROUP BY
    market_date
HAVING count(1) > 3
ORDER BY 
    market_date
;




     """,conn).head(10)
# Out:
#   market_date  customer_id  No_of_Transactions  avgspent
# 0  2019-04-03            5                  21     22.24
# 1  2019-04-06            2                  24     22.73
# 2  2019-04-10            4                  23     21.96
# 3  2019-04-13            2                  19     19.42
# 4  2019-04-17            1                  25     19.60
# 5  2019-04-20            2                  23     19.28
# 6  2019-04-24            1                  24     14.92
# 7  2019-04-27            2                  19     23.21
# 8  2019-05-01            1                  26     20.12
# 9  2019-05-04            7                  23     20.57

# %% [markdown]
# #### Q: FILTER OUT VENDORS WHO BROUGHT ATLEAST 10 ITMES TO FARMERS MARKET OVER THE PERIOD 2019-05-02 AND 2019-05-16

# %%
pd.read_sql_query("""

select 
    vendor_id,
    count(distinct(product_id)) as No_of_items,
    sum(quantity * original_price) as value_of_inventory,
    sum(quantity) as inventory_item_count
from 
    vendor_inventory
where 
    market_date between "2019-05-02" and "2019-05-16" 
group by 
    vendor_id
having 
    inventory_item_count >=10
;



     """,conn).head(10)
# Out:
#    vendor_id  No_of_items  value_of_inventory  inventory_item_count
# 0          7            1               560.0                 140.0
# 1          8            3              1605.0                 139.0

# %% [markdown]
# #### Question: count how many products were on sale for each market_date, or how many different products each vendor offered.

# %%
pd.read_sql_query("""


SELECT
    market_date,
    vendor_id,
    COUNT(distinct(product_id)) as differentProducts
from 
    CUSTOMER_PURCHASES
group by
    market_date, vendor_id
order by 
    market_date;


     """,conn).head(10)
# Out:
#   market_date  vendor_id  differentProducts
# 0  2019-04-03          7                  1
# 1  2019-04-03          8                  3
# 2  2019-04-06          7                  1
# 3  2019-04-06          8                  3
# 4  2019-04-10          7                  1
# 5  2019-04-10          8                  3
# 6  2019-04-13          7                  1
# 7  2019-04-13          8                  3
# 8  2019-04-17          7                  1
# 9  2019-04-17          8                  3
