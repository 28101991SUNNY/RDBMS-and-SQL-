# %%
pd.set_option('display.max_rows',1500)
import mysql.connector as connection
import pymysql
dbname = "farmers_market"
dbhost = "localhost"
dbusername = "root"
dbpassword = "9723811710"
conn = pymysql.connect(host = dbhost,
                           port = int(3306),
                             user = "root",
                             passwd = dbpassword,
                            db = dbname)
# %load_ext sql
# %sql mysql+mysqldb://root:9723811710@localhost/farmers_market

# %% [markdown]
# ### What is a common table expression or CTE

# %% [markdown]
# - A common table expression is a named temporary result set that exists only within the execution scope of a single SQL statement e.g.,SELECT, INSERT, UPDATE, or DELETE.
#
# - Similar to a derived table, a CTE is not stored as an object and last only during the execution of a query.
#
# - Unlike a derived table, a CTE can be self-referencing (a recursive CTE) or can be referenced multiple times in the same query. In addition, a CTE provides better readability and performance in comparison with a derived table.

# %% [markdown]
# #### MySQL CTE syntax :
#
# - The structure of a CTE includes the name, an optional column list, and a query that defines the CTE.
# - After the CTE is defined, you can use it as a view in a SELECT, INSERT, UPDATE, DELETE, or CREATE VIEW statement.
#
# - The following illustrates the basic syntax of a CTE:
#
#         WITH cte_name (column_list) AS (
#             query
#         )
#         SELECT * FROM cte_name;
#
#
# - Notice that the number of columns in the query must be the same as the number of columns in the column_list. If you omit the column_list, the CTE will use the column list of the query that defines the CTE

# %%
pd.read_sql_query("""

select * from customer_purchases;

""",conn)
# Out:
#       product_id  vendor_id market_date  customer_id  quantity  \
# 0              1          7  2019-07-03           14      0.99
# 1              1          7  2019-07-03           14      2.18
# 2              1          7  2019-07-03           15      1.53
# 3              1          7  2019-07-03           16      2.02
# 4              1          7  2019-07-03           22      0.66
# ...          ...        ...         ...          ...       ...
# 4216          16          4  2020-09-30            4      2.00
# 4217          16          4  2020-09-30           11      1.00
# 4218          16          4  2020-09-30           16      5.00
# 4219          16          4  2020-09-30           18      6.00
# 4220          16          4  2020-09-30           18      4.00
#
#       cost_to_customer_per_qty transaction_time
# 0                         6.99  0 days 17:32:00
# 1                         6.99  0 days 18:23:00
# 2                         6.99  0 days 18:41:00
# ...

# %%
# CREATE A CUSTOME DATASET TO TRACK SALES OVER TIME 
#

# %%
pd.read_sql_query("""

select
    market_date,
    vendor_id,
    sum(quantity * cost_to_customer_per_qty)  as Total_Sales
from
    customer_purchases
group by market_date,vendor_id 
order by market_date , vendor_id
;
    

""",conn)
# Out:
#     market_date  vendor_id  Total_Sales
# 0    2019-04-03          7      76.0000
# 1    2019-04-03          8     399.0000
# 2    2019-04-06          7     112.0000
# 3    2019-04-06          8     437.5000
# 4    2019-04-10          7      92.0000
# 5    2019-04-10          8     413.0000
# 6    2019-04-13          7     104.0000
# 7    2019-04-13          8     273.0000
# 8    2019-04-17          7     122.5000
# 9    2019-04-17          8     371.0000
# 10   2019-04-20          7      80.0000
# 11   2019-04-20          8     375.5000
# 12   2019-04-24          7     108.0000
# 13   2019-04-24          8     258.0000
# 14   2019-04-27          7     101.5000
# 15   2019-04-27          8     343.0000
# 16   2019-05-01          7      84.0000
# 17   2019-05-01          8     439.0000
# 18   2019-05-04          7     100.0000
# 19   2019-05-04          8     397.0000
# 20   2019-05-08          7      88.0000
# 21   2019-05-08          8     406.5000
# ...

# %%
pd.read_sql_query("""



select
    
    week(market_date) 'week',
    monthname(market_date) month_name,
    sum(quantity * cost_to_customer_per_qty)  as Total_Sales
from
    customer_purchases
group by week(market_date)
order by year(market_date),month(market_date)
    

;
    

""",conn)
# Out:
#     week month_name  Total_Sales
# 0     13      April    1646.0000
# 1     14      April    1603.0000
# 2     15      April    1542.5000
# 3     16      April    1522.5000
# 4     20        May    1679.5000
# 5     17        May    1860.5000
# 6     18        May    2069.0000
# 7     19        May    1739.5000
# 8     21        May    2080.1000
# 9     25       June    2092.2000
# 10    24       June    1748.8000
# 11    23       June    2089.7000
# 12    22       June    1718.0000
# 13    26       July    1835.2076
# 14    27       July    1816.8933
# 15    28       July    1965.3058
# 16    29       July    1833.4831
# 17    30       July    1543.9977
# 18    32     August    2079.8844
# 19    33     August    1808.1762
# 20    34     August    2062.7907
# 21    31     August    1857.9947
# 22    38  September    1766.9626
# 23    37  September    1929.8400
# 24    36  September    2123.8121
# 25    35  September    1744.2244
# 26    40    October    2152.5000
# ...

# %%
pd.read_sql_query("""



select
    year(market_date) as 'year',
    monthname(market_date) 'month_name',
    sum(quantity * cost_to_customer_per_qty)  as Total_Sales
from
    customer_purchases
group by month(market_date)
order by year(market_date),month(market_date)
    

;
    

""",conn)
# Out:
#    year month_name  Total_Sales
# 0  2019      April    6688.0000
# 1  2019        May    8562.5000
# 2  2019       June    8140.8000
# 3  2019       July    8180.3788
# 4  2019     August    8623.3547
# 5  2019  September    8089.1032
# 6  2019    October    6230.5000
# 7  2019   November    5601.0000
# 8  2019   December    5378.5000
# 9  2020      March    3733.0000

# %%
pd.read_sql_query("""

select
    cp.market_date,
    cp.vendor_id,
    mdi.market_day,
    mdi.market_week,
    mdi.market_year,
    v.vendor_name,
    v.vendor_type,
    round(sum(cp.quantity * cp.cost_to_customer_per_qty),2)  as Total_Sales
from
    customer_purchases as cp
    join vendor as v
        on v.vendor_id = cp.vendor_id
    join market_date_info as mdi
        on mdi.market_date = cp.market_date
group by cp.market_date , cp.vendor_id
order by cp.market_date , cp.vendor_id
;
    

""",conn)
# Out:
#     market_date  vendor_id market_day market_week market_year  \
# 0    2019-04-03          7  Wednesday          14        2019
# 1    2019-04-03          8  Wednesday          14        2019
# 2    2019-04-06          7   Saturday          14        2019
# 3    2019-04-06          8   Saturday          14        2019
# 4    2019-04-10          7  Wednesday          15        2019
# 5    2019-04-10          8  Wednesday          15        2019
# 6    2019-04-13          7   Saturday          15        2019
# 7    2019-04-13          8   Saturday          15        2019
# 8    2019-04-17          7  Wednesday          16        2019
# 9    2019-04-17          8  Wednesday          16        2019
# 10   2019-04-20          7   Saturday          16        2019
# 11   2019-04-20          8   Saturday          16        2019
# 12   2019-04-24          7  Wednesday          17        2019
# 13   2019-04-24          8  Wednesday          17        2019
# ...

# %%
# COMMON TABLE EXPRESSIONS:

# %%
pd.read_sql_query("""

WITH

    purchase_details_by_day_by_vendor
                    AS
                    (
                    select
                        cp.market_date,
                        cp.vendor_id,
                        mdi.market_day,
                        mdi.market_week,
                        mdi.market_year,
                        v.vendor_name,
                        v.vendor_type,
                        round(sum(cp.quantity * cp.cost_to_customer_per_qty),2)  as Total_Sales
                    from
                        customer_purchases as cp
                        join vendor as v
                            on v.vendor_id = cp.vendor_id
                        join market_date_info as mdi
                            on mdi.market_date = cp.market_date
                    group by cp.market_date , cp.vendor_id
                    order by cp.market_date , cp.vendor_id
                    ),
                    
    purchase_details_monthly
                    AS
                    (
                    select 
                        market_year,
                        monthname(market_date),
                        vendor_name,
                        vendor_type,
                        sum(Total_Sales)
                    from
                        purchase_details_by_day_by_vendor
                    group by 
                        market_year,monthname(market_date),vendor_id
                        
                    )
                    
                    
SELECT * FROM purchase_details_monthly

;
    



""",conn)
# Out:
#    market_year monthname(market_date)      vendor_name     vendor_type  \
# 0         2019                  April  Marco's Peppers   Fresh Focused
# 1         2019                  April     Annie's Pies  Prepared Foods
# 2         2019                    May  Marco's Peppers   Fresh Focused
# 3         2019                    May     Annie's Pies  Prepared Foods
# 4         2019                   June   Fields of Corn   Fresh Focused
# 5         2019                   June  Marco's Peppers   Fresh Focused
# 6         2019                   June     Annie's Pies  Prepared Foods
# 7         2019                   July   Fields of Corn   Fresh Focused
# 8         2019                   July  Marco's Peppers   Fresh Focused
# 9         2019                   July     Annie's Pies  Prepared Foods
# 10        2019                 August   Fields of Corn   Fresh Focused
# 11        2019                 August  Marco's Peppers   Fresh Focused
# ...

# %%
pd.read_sql_query("""


select
    cp.vendor_id,
    mdi.market_year,
    monthname(mdi.market_date),
    v.vendor_name,
    v.vendor_type,
    round(sum(cp.quantity * cp.cost_to_customer_per_qty),2)  as Total_Sales
from
    customer_purchases as cp
    join vendor as v
        on v.vendor_id = cp.vendor_id
    join market_date_info as mdi
        on mdi.market_date = cp.market_date
group by mdi.market_year,monthname(mdi.market_date),cp.vendor_id
order by cp.market_date , cp.vendor_id

;




""",conn)
# Out:
#     vendor_id market_year monthname(mdi.market_date)      vendor_name  \
# 0           7        2019                      April  Marco's Peppers
# 1           8        2019                      April     Annie's Pies
# 2           7        2019                        May  Marco's Peppers
# 3           8        2019                        May     Annie's Pies
# 4           4        2019                       June   Fields of Corn
# 5           7        2019                       June  Marco's Peppers
# 6           8        2019                       June     Annie's Pies
# 7           4        2019                       July   Fields of Corn
# 8           7        2019                       July  Marco's Peppers
# 9           8        2019                       July     Annie's Pies
# 10          4        2019                     August   Fields of Corn
# 11          7        2019                     August  Marco's Peppers
# ...

# %%
# pd.read_sql_query("""


# select
# *
# from
# customer_purchases;



# """,conn)

# %% [markdown]
# #  MySQL Views

# %% [markdown]
# ### Advantages of MySQL Views
# - MySQL views bring the following advantages.
#
# 1) Simplify complex query
#
# - Views help simplify complex queries. If you have any frequently used complex query, you can create a view based on it so that you can reference to the view by using a simple SELECT statement instead of typing the query all over again.
#
# 2) Make the business logic consistent
#
# - Suppose you have to repeatedly write the same formula in every query.  Or you have a query that has complex business logic. To make this logic consistent across queries, you can use a view to store the calculation and hide the complexity.
#
# 3) Add extra security layers
#
# - A table may expose a lot of data including sensitive data such as personal and banking information.
#
# - By using views and privileges, you can limit which data users can access by exposing only the necessary data to them.
#
# - For example, the table employees may contain SSN and address information, which should be accessible by the HR department only.
#
# - To expose general information such as first name, last name, and gender to the General Administration (GA) department, you can create a view based on these columns and grant the users of the GA department to the view, not the entire table employees .
#
# 4) Enable backward compatibility
#
# - In legacy systems, views can enable backward compatibility.
#
# - Suppose, you want to normalize a big table into many smaller ones. And you don’t want to impact the current applications that reference the table.
#
# - In this case, you can create a view whose name is the same as the table based on the new tables so that all applications can reference the view as if it were a table.
#
# - Note that a view and table cannot have the same name so you need to drop the table first before creating a view whose name is the same as the deleted table.
#
# #### Managing views in MySQL
# - Create views – show you how to use the CREATE VIEW statement to create a new view in the database.
# - Understand view processing algorithms – learn how MySQL process a view.
# - Create updatable views – learn how to create updatable views.
# - Create views with a WITH CHECK OPTION – ensure the consistency of views  using the WITH CHECK OPTION clause.
# - LOCAL & CASCADED and WITH CHECK OPTION – specify the scope of the check with LOCAL and CASCADED options.
# - Drop views – guide you on how to remove one or more existing views.
# - Show views – provide ways to find views in a database.
# - Rename views – change the name of a view to another.

# %% [markdown]
# ### MySQL CREATE VIEW :
#
#
#
# ##### introduction to MySQL CREATE VIEW statement:
# - The CREATE VIEW statement creates a new view in the database. Here is the basic syntax of the CREATE VIEW statement:
#
#         CREATE [OR REPLACE] VIEW [db_name.]view_name [(column_list)]
#         AS
#           select-statement;
#         Code language: SQL (Structured Query Language) (sql)
#
# - In this syntax:
#
# - First, specify the name of the view that you want to create after the CREATE VIEW keywords. The name of the view is unique in a database. Because views and tables in the same database share the same namespace, the name a view cannot the same as the name of an existing table.
#
# - Second, use the OR REPLACE option if you want to replace an existing view if the view already exists. If the view does not exist, the OR REPLACE has no effect.
#
# - Third, specify a list of columns for the view. By default, the columns of the view are derived from the select list of the SELECT statement. However, you can explicitly specify the column list for the view by listing them in parentheses following the view name.
#
# - Finally,  specify a SELECT statement that defines the view. The SELECT  statement can query data from tables or views. MySQL allows you to use the ORDER BY clause in the SELECT statement but ignores it if you select from the view with a query that has its own ORDER BY clause.
#
# - By default, the CREATE VIEW statement creates a view in the current database. If you want to explicitly create a view in a given database, you can qualify the view name with the database name.

# %% [markdown]
# ref : https://www.mysqltutorial.org/create-sql-views-mysql.aspx

# %% [markdown]
#     Introduction to MySQL ALTER VIEW statement
#     The MySQL ALTER VIEW statement changes the definition of an existing view. The syntax of the ALTER VIEW is similar to the CREATE VIEW statement:
#
#     ALTER
#         [ALGORITHM = {UNDEFINED | MERGE | TEMPTABLE}]
#         VIEW view_name [(column_list)]
#         AS select_statement;

# %% [markdown]
#     CREATE VIEW  farmers_vendor_total_weekly_sales   AS
#
#         SELECT
#
#             year(cp.market_date) as market_year,
#             monthname(cp.market_date) as market_month,
#             week(cp.market_date) as market_week,
#             cp.vendor_id,
#             v.vendor_name,
#             v.vendor_type,
#             sum(cp.quantity*cp.cost_to_customer_per_qty) as Total_Sales_weekly
#
#         FROM
#             customer_purchases as cp
#             join vendor as v
#                 on v.vendor_id = cp.vendor_id
#
#         GROUP BY
#             cp.vendor_id,year(cp.market_date),monthname(cp.market_date),week(cp.market_date)
#         ORDER BY
#             year(cp.market_date),month(cp.market_date),week(cp.market_date)

# %%
pd.read_sql_query("""


select * from 
        farmers_vendor_total_weekly_sales;


""",conn)
# Out:
#      market_year market_month  market_week  vendor_id      vendor_name  \
# 0           2019        April           13          7  Marco's Peppers
# 1           2019        April           13          8     Annie's Pies
# 2           2019        April           14          7  Marco's Peppers
# 3           2019        April           14          8     Annie's Pies
# 4           2019        April           15          7  Marco's Peppers
# 5           2019        April           15          8     Annie's Pies
# 6           2019        April           16          7  Marco's Peppers
# 7           2019        April           16          8     Annie's Pies
# 8           2019          May           17          7  Marco's Peppers
# 9           2019          May           17          8     Annie's Pies
# 10          2019          May           18          7  Marco's Peppers
# 11          2019          May           18          8     Annie's Pies
# ...

# %%
pd.read_sql_query("""


select 
market_year,
market_month,
sum(Total_Sales_weekly)

from 
    farmers_vendor_total_weekly_sales
group by 
    market_year,market_month
;


""",conn)
# Out:
#     market_year market_month  sum(Total_Sales_weekly)
# 0          2019        April                3666.0000
# 1          2019          May                4428.0000
# 2          2019         June                4317.7000
# 3          2019         July                4358.5025
# 4          2019       August                4263.7140
# 5          2019    September                3702.5423
# 6          2019      October                4521.0000
# 7          2019     November                5601.0000
# 8          2019     December                5378.5000
# 9          2020        March                3733.0000
# 10         2020        April                3022.0000
# 11         2020          May                4134.5000
# 12         2020         June                3823.1000
# 13         2020         July                3821.8763
# 14         2020       August                4359.6407
# 15         2020    September                4386.5609
# ...

# %%
pd.read_sql_query("""


select 
vendor_name,
sum(Total_Sales_weekly) total_sale_per_vendor

from 
    farmers_vendor_total_weekly_sales
group by 
    vendor_name
;


""",conn)
# Out:
#        vendor_name  total_sale_per_vendor
# 0  Marco's Peppers             18403.0367
# 1     Annie's Pies             49630.0000
# 2   Fields of Corn              1194.1000

# %%
pd.set_option('display.max_rows',1500)
import mysql.connector as connection
import pymysql
dbname = "hr"
dbhost = "localhost"
dbusername = "root"
dbpassword = "9723811710"
conn = pymysql.connect(host = dbhost,
                           port = int(3306),
                             user = "root",
                             passwd = dbpassword,
                            db = dbname)
# %load_ext sql
# %sql mysql+mysqldb://root:9723811710@localhost/hr
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Extract all the employees who work under the same manager. Return manager_id and managers full name (first name, last name separated by space) as 'Manager' and employee's full name (first name, last name separated by space) as 'Employee' and order the data based on manager_id and 'Employee'.

# %%
pd.read_sql_query("""


select 

e.manager_id,
concat(m.first_name , " ", m.last_name) as Manager,

concat(e.first_name , " ", e.last_name) as Employee
from
employees as e
join employees as m
on
e.manager_id = m.employee_id
order by e.manager_id , e.first_name
;


""",conn)
# Out:
#     manager_id            Manager           Employee
# 0          100        Steven King         Adam Fripp
# 1          100        Steven King  Alberto Errazuriz
# 2          100        Steven King       Den Raphaely
# 3          100        Steven King      Eleni Zlotkey
# 4          100        Steven King   Gerald Cambrault
# 5          100        Steven King       John Russell
# 6          100        Steven King     Karen Partners
# 7          100        Steven King      Kevin Mourgos
# 8          100        Steven King        Lex De Haan
# 9          100        Steven King      Matthew Weiss
# 10         100        Steven King  Michael Hartstein
# 11         100        Steven King      Neena Kochhar
# 12         100        Steven King     Payam Kaufling
# 13         100        Steven King     Shanta Vollman
# 14         101      Neena Kochhar       Hermann Baer
# 15         101      Neena Kochhar    Jennifer Whalen
# 16         101      Neena Kochhar    Nancy Greenberg
# ...

# %% [markdown]
# ### Problem Statement:
#
# ### Use CTE's. Add 5000 for every employee's salary and save the column as 'Net_salary' and display all the details like employee_id,first_name, last_name, salary , 'Net_salary' of those employees whose net salary is greater than 20000.
#
# Return the columns 'employee_id', 'first_name', 'last_name', 'salary', 'Net_Salary'.

# %%
# pd.read_sql_query("""


# select 
# employee_id,
# first_name,
# last_name,
# salary,
# salary + 5000 as 'Net_Salary'

# from
# employees

# ;


# """,conn)

# %%
pd.read_sql_query("""


WITH emp AS
    (
        select 
            *,
            salary + 5000 as 'Net_Salary'

        from
            employees
    )
SELECT 
    employee_id,
    first_name,
    last_name,
    salary,
    Net_salary
FROM
    emp
WHERE 
    Net_Salary >= 20000


;


""",conn)
# Out:
#    employee_id first_name last_name  salary  Net_Salary
# 0          100     Steven      King   25000       30000
# 1          101      Neena   Kochhar   17000       22000
# 2          102        Lex   De Haan   17000       22000

# %% [markdown]
# ### Problem Statement:
#
# ### Use CTE's. Calculate the net salary for the employees and save the column as 'Net_salary' and display all the details like employee_id,first_name, last_name, salary , 'Net_salary' of those employees whose net salary is greater than 15000.
#
# ### Note: To calculate the 'Net_salary' = salary + salary *(comission_pct). If the column 'comission_pct' consists of null values replace them with zeros using the ifnull() function. For example: ifnull(comission_pct,0).
#
# Return the columns 'employee_id', 'first_name', 'last_name', 'salary', 'Net_Salary'.

# %%
pd.read_sql_query("""


WITH emp AS
    (
        select 
            *,
            salary+(salary*ifnull(commission_pct,0)) as Net_Salary
        from
            employees
    )
SELECT 
    employee_id,
    first_name,
    last_name,
    salary,
    Net_salary
    
FROM
    emp
WHERE 
    Net_Salary >= 15000

;


""",conn)
# Out:
#    employee_id first_name  last_name  salary  Net_Salary
# 0          100     Steven       King   25000     25000.0
# 1          101      Neena    Kochhar   17000     17000.0
# 2          102        Lex    De Haan   17000     17000.0
# 3          145       John    Russell   14000     19600.0
# 4          146      Karen   Partners   13500     17550.0
# 5          147    Alberto  Errazuriz   12000     15600.0

# %% [markdown]
# ### Display all the employee information who work for department number 80 or have salary more than 10000 using Union for employees table.
#
# Return all the columns

# %%
(pd.read_sql_query("""


SELECT 
*
FROM
employees
where department_id = 80

UNION

SELECT 
*
FROM
employees
WHERE
salary >= 1000


;


""",conn))
# Out:
#      employee_id   first_name    last_name     email        phone_number  \
# 0            145         John      Russell   JRUSSEL  011.44.1344.429268
# 1            146        Karen     Partners  KPARTNER  011.44.1344.467268
# 2            147      Alberto    Errazuriz  AERRAZUR  011.44.1344.429278
# 3            148       Gerald    Cambrault  GCAMBRAU  011.44.1344.619268
# 4            149        Eleni      Zlotkey  EZLOTKEY  011.44.1344.429018
# 5            150        Peter       Tucker   PTUCKER  011.44.1344.129268
# 6            151        David    Bernstein  DBERNSTE  011.44.1344.345268
# 7            152        Peter         Hall     PHALL  011.44.1344.478968
# 8            153  Christopher        Olsen    COLSEN  011.44.1344.498718
# 9            154      Nanette    Cambrault  NCAMBRAU  011.44.1344.987668
# 10           155       Oliver      Tuvault  OTUVAULT  011.44.1344.486508
# 11           156      Janette         King     JKING  011.44.1345.429268
# ...

# %% [markdown]
# ### Problem Statement:
#
# ### create a view as 'empview' that has the details like employeeid, firstname, lastname, salary, departmentid, departmentname, locationid, streetaddress, city. Print from the view of all those employees who are from the cities Seattle or Southlake and display all the records in the emp_view.
#
# Return the view with columns 'employee_id', 'first_name', 'last_name', 'salary', 'department_id', 'department_name', 'location_id', 'street_address', 'city'.

# %% [markdown]
#     CREATE VIEW  empview   AS
#
#         SELECT
#             e.employee_id,
#             e.first_name,
#             e.last_name,
#             e.salary,
#             e.department_id,
#             d.department_name,
#             d.location_id,
#             l.street_address,
#             l.city
#         FROM
#             employees as e
#                 join departments as d
#                     on d.department_id = e.department_id
#                 join locations as l
#                     on l.location_id = d.location_id

# %%
pd.read_sql_query("""

select 
*
from
empview
where
city in ("Seattle","Southlake")

;


""",conn)
# Out:
#     employee_id   first_name   last_name  salary  department_id  \
# 0           100       Steven        King   25000             90
# 1           101        Neena     Kochhar   17000             90
# 2           102          Lex     De Haan   17000             90
# 3           103    Alexander      Hunold    9000             60
# 4           104        Bruce       Ernst    6000             60
# 5           105        David      Austin    4800             60
# 6           106        Valli   Pataballa    4800             60
# 7           107        Diana     Lorentz    4200             60
# 8           108        Nancy   Greenberg   12000            100
# 9           109       Daniel      Faviet    9000            100
# 10          110         John        Chen    8200            100
# 11          111       Ismael     Sciarra    7700            100
# 12          112  Jose Manuel       Urman    7800            100
# 13          113         Luis        Popp    6900            100
# ...

# %% [markdown]
# ### Extract all the id's of the managers(only distinct values) from both the "Employees" and the "Departments" table.
#
# Return the column 'manager_id'.

# %%
pd.read_sql_query("""

select 
distinct(manager_id)
from
departments

union

select
distinct(manager_id)
from 
employees

order by manager_id


;

""",conn)
# Out:
#    manager_id
# 0        None
# 1         100
# 2         101
# 3         102
# 4         103
# 5         108
# 6         114
# 7         120
# 8         121
# 9         122
# 10        123
# 11        124
# 12        145
# 13        146
# 14        147
# 15        148
# 16        149
# 17        200
# 18        201
# 19        203
# 20        204
# 21        205

# %% [markdown]
# #### Problem Statement:
#
# ### Use CTEs and display the 12th highest salary from the employee's table.
#
# Return the column 'salary'.

# %%
pd.read_sql_query("""


WITH emp AS
    (
        SELECT
            *,
            dense_rank() over(order by salary desc) salary_dense_rank
        FROM
            employees
        
    )
SELECT 
    distinct
    salary
    
FROM
    emp
where 
    salary_dense_rank = 12

;


""",conn)
# Out:
#    salary
# 0    9500

# %% [markdown]
# #### Problem Statement:
#
# ### Create a view as 'Manager_details' with Manager's employee id, manager's name(first name and last name separated by space) as 'Manager' salary, phone number, department id and name, street address, city, country name.
# ### Display the details employee_id, Manager, salary, and department_name from the view 'Manager_details' of those Top 5 managers with the highest salary.
#
# Return the view with columns 'employee_id', 'Manager', 'salary', 'phone_number', 'department_id', 'department_name' , 'street_address', 'city', 'country_name'.

# %% [markdown]
#     CREATE VIEW  Manager_details   AS
#
#         select
#             distinct
#             m.employee_id,
#             concat(m.first_name," ",m.last_name) as manager,
#             m.salary,
#             m.department_id,
#             d.department_name,
#             l.street_address,
#             c.country_name
#         from
#             employees as m
#                 join employees as e
#                 on m.employee_id = e.manager_id
#             left join departments as d
#                 on d.department_id = m.department_id
#             left join locations as l
#                 on l.location_id = d.location_id
#             left join countries as c
#                 on c.country_id = l.country_id

# %%
pd.read_sql_query("""


select 
    employee_id,
    manager,
    salary,
    department_name
from 
    Manager_details
order by 
    salary desc
limit 5
""",conn)
# Out:
#    employee_id         manager  salary department_name
# 0          100     Steven King   25000       Executive
# 1          102     Lex De Haan   17000       Executive
# 2          101   Neena Kochhar   17000       Executive
# 3          145    John Russell   14000           Sales
# 4          146  Karen Partners   13500           Sales
